# %%
import pandas as pd 
import numpy as np

# %%
# step-1: create df using list
name=['Ramesh','Kishore','Joseph']

# %%
#pd.DataFrame(data,index,columns)

# %%
pd.DataFrame(name,index=['A','B','C'],columns=['Names'])
# Out:
#      Names
# A   Ramesh
# B  Kishore
# C   Joseph

# %%
#step-2:-
name=['Ramesh','Kishore','Joseph']
age=[22,23,24]
pd.DataFrame(zip(name,age),columns=['Names','Age'])
# Out:
#      Names  Age
# 0   Ramesh   22
# 1  Kishore   23
# 2   Joseph   24

# %%
# step-3:- Create a df using dictionary
d={'Names':['Ramesh','Kishore','Joseph'],
   'Age':[20,22,23],
   'City':['Koppedu','Puttur','Tirupati']}
d
# Out:
# {'Names': ['Ramesh', 'Kishore', 'Joseph'],
#  'Age': [20, 22, 23],
#  'City': ['Koppedu', 'Puttur', 'Tirupati']}

# %%
pd.DataFrame(d)
# Out:
#      Names  Age      City
# 0   Ramesh   20   Koppedu
# 1  Kishore   22    Puttur
# 2   Joseph   23  Tirupati

# %%
# step-4: Selection updation and add column
# select the column
# update the column
# Add new column

# %%
d={'Names':['Ramesh','Kishore','Joseph'],
   'Age':[20,22,23]}
df=pd.DataFrame(d)
df
# Out:
#      Names  Age
# 0   Ramesh   20
# 1  Kishore   22
# 2   Joseph   23

# %%
# selection
df['Names']
# Out:
# 0     Ramesh
# 1    Kishore
# 2     Joseph
# Name: Names, dtype: object

# %%
df['names']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'names'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df['names']
#
# ...

# %%
# uppdation
df['Age']
# Out:
# 0    20
# 1    22
# 2    23
# Name: Age, dtype: int64

# %%
df['City']=['koppedu','Hyd','Tirupati',]
df
# Out:
#      Names  Age      City
# 0   Ramesh   20   koppedu
# 1  Kishore   22       Hyd
# 2   Joseph   23  Tirupati

# %%
# specific value
df.replace('Ramesh','Dhanusha')
# Out:
#       Names  Age      City
# 0  Dhanusha   20   koppedu
# 1   Kishore   22       Hyd
# 2    Joseph   23  Tirupati

# %%
# inplace = we need to python
#           out put should be overwrite 
df.replace('Ramesh','Dr.Dhanusha',inplace=True)
df
# Out:
#          Names  Age      City
# 0  Dr.Dhanusha   20   koppedu
# 1      Kishore   22       Hyd
# 2       Joseph   23  Tirupati

# %%
# condition
df['Age']=np.where(df['Names']=='Joseph',65,df['Age'])
df
# Out:
#          Names  Age      City
# 0  Dr.Dhanusha   20   koppedu
# 1      Kishore   22       Hyd
# 2       Joseph   65  Tirupati

# %%
l=[]
for i,j in zip(df['Names'],df['Age']):
    if  i=='Joseph':
        l.append(25)
    else:
        l.append(j)
df['Age']=l

# %%
df
# Out:
#          Names  Age      City
# 0  Dr.Dhanusha   20   koppedu
# 1      Kishore   22       Hyd
# 2       Joseph   25  Tirupati

# %%
# how to drop a column

# %%
df
# Out:
#          Names  Age      City
# 0  Dr.Dhanusha   20   koppedu
# 1      Kishore   22       Hyd
# 2       Joseph   65  Tirupati

# %%
#df.drop(labels,axis,index,columns)
#df.drop==== i can drop column, or i can drop index
# labels === either column or index 
#df.drop('City') # THIS CITY MIGHT BE INDEX , OR MIGHT BE COLUMNS
# Python ceckes axis =0

# %%
df.drop('City',axis=1) # inplace
# Out:
#          Names  Age
# 0  Dr.Dhanusha   20
# 1      Kishore   22
# 2       Joseph   65

# %%
df.drop(1,axis=0)
# Out:
#          Names  Age      City
# 0  Dr.Dhanusha   20   koppedu
# 2       Joseph   65  Tirupati

# %%
df.drop(0,axis=0)
# Out:
#      Names  Age      City
# 1  Kishore   22       Hyd
# 2   Joseph   65  Tirupati

# %%
df.replace('Joseph','G.JOseph')
# Out:
#          Names  Age      City
# 0  Dr.Dhanusha   20   koppedu
# 1      Kishore   22       Hyd
# 2     G.JOseph   65  Tirupati

# %%
df.drop(2,axis=0)
# Out:
#          Names  Age     City
# 0  Dr.Dhanusha   20  koppedu
# 1      Kishore   22      Hyd

# %%
df
# Out:
#          Names  Age      City
# 0  Dr.Dhanusha   20   koppedu
# 1      Kishore   22       Hyd
# 2       Joseph   65  Tirupati

# %%
df=df.drop(index=[1],columns=['City'])
df
# Out:
#          Names  Age
# 0  Dr.Dhanusha   20
# 2       Joseph   65
