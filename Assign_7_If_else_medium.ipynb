# %%
x =10
if x>5:
    print('A')
if x>8:
    print('B')
else:
    print('c')
# Out:
# A
# B

# %%
x=6
if x >5:
    print('A')
    
if x >10:
    print('B')
else:
    print('C')
# Out:
# A
# C

# %%
x=5
if x ==5:
    print('A')
elif x>=5:
    print('B')
else:
    print('C')
# Out:
# A

# %%
x = 6
if x == 5:
    print('a')
elif x>=5:
    print('b')
else:
    print('c')
# Out:
# b

# %%
x = 4
if x == 5:
    print('a')
elif x>=5:
    print('b')
else:
    print('c')
# Out:
# c

# %%
a=5
b=5
if a== b:
    print('Equal')
elif a >b:
    print('A')
else:
    print('B')
# Out:
# Equal

# %%
x =10
if x %2 ==0 and x> 5:
    print('A')
else:
    print('B')
# Out:
# A

# %%
x=7
if x%2==0 or x>5:
    print('Yes')
else:
    print('No')
# Out:
# Yes

# %%
x=4 
if x%2==0 and x>5:
    print('A')
elif x%2==0:
    print('B')
else:
    print('C')
# Out:
# B

# %%
x=9
if x%2==0:
    print('Even')
elif x%3==0:
    print('dived by 3')
else:
    print('Others')
# Out:
# dived by 3

# %%
x =10
if x >5:
    if x>8: 
        if x<15:
            print('A')
        else:
            print('B')
    else:
        print('C')
else:
    print('D')
# Out:
# A

# %%
x = 4
if x > 5:
    if x>8:
        print('A')
    else:
        print('B')
else:
    print('C')
# Out:
# C

# %%
x = 10 
if x > 5 and x <20 or x ==100:
    print('A')
else:
    print('B')
# Out:
# A

# %%
x = 100
if x > 5 and x <20 or x ==100:
    print('A')
else:
    print('B')
# Out:
# A

# %%
x = 100
if x > 5 and (x <20 or x ==100):
    print('A')
else:
    print('B')
# Out:
# A

# %%
x = 4
if x > 5 or x <20 and x ==100:
    print('A')
else:
    print('B')
# Out:
# B

# %%
x = 4
if (x > 5 or x <20 )and x ==100:
    print('A')
else:
    print('B')
# Out:
# B

# %%
x = 0
if x and 10/x>1:
    print('A')
else:
    print('B')
# Out:
# B

# %%
x = 1
if x or 10 / 0>1:
    print('A')
else:
    print('B')
# Out:
# A
